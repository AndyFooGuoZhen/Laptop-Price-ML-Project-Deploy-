# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading laptop prices dataset

# %%
df=pd.read_csv('laptops.csv',encoding='ISO-8859–1')
df
# Out:
#       Unnamed: 0 Company                              Product  \
# 0              1   Apple                          MacBook Pro
# 1              2   Apple                          Macbook Air
# 2              3      HP                               250 G6
# 3              4   Apple                          MacBook Pro
# 4              5   Apple                          MacBook Pro
# ...          ...     ...                                  ...
# 1298        1316  Lenovo                       Yoga 500-14ISK
# 1299        1317  Lenovo                       Yoga 900-13ISK
# 1300        1318  Lenovo                   IdeaPad 100S-14IBR
# 1301        1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302        1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# # Basic dataset exploration

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'Product', 'TypeName', 'Inches',
#        'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price_euros'],
#       dtype='object')

# %% [markdown]
# Columns Unamed and product were dropped as they don't contain any useful information for model training later. Laptop brands will be dropped for error prone prediction later, (doesnt make sense to have apple laptops running windows). This would ultimately be a GENERAL LAPTOP PRICE PREDICTOR.

# %%
df=df.drop(columns=['Unnamed: 0','Product','Company'])
df.head(10)
# Out:
#     TypeName  Inches                    ScreenResolution  \
# 0  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1  Ultrabook    13.3                            1440x900
# 2   Notebook    15.6                   Full HD 1920x1080
# 3  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 5   Notebook    15.6                            1366x768
# 6  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 7  Ultrabook    13.3                            1440x900
# 8  Ultrabook    14.0                   Full HD 1920x1080
# 9  Ultrabook    14.0         IPS Panel Full HD 1920x1080
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# ...

# %%
df.isnull().sum() #no missing values
# Out:
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.dtypes
# Out:
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %%
explorecols=['TypeName','Cpu','Gpu','Inches','Ram','Memory','OpSys','Weight']

for i in explorecols:
    print("%-10s\n%-200s\n%-10d\n"%(i,df[i].unique(),df[i].nunique()))
# Out:
# TypeName
# ['Ultrabook' 'Notebook' 'Netbook' 'Gaming' '2 in 1 Convertible'
#  'Workstation']
# 6
#
# Cpu
# ['Intel Core i5 2.3GHz' 'Intel Core i5 1.8GHz'
#  'Intel Core i5 7200U 2.5GHz' 'Intel Core i7 2.7GHz'
#  'Intel Core i5 3.1GHz' 'AMD A9-Series 9420 3GHz' 'Intel Core i7 2.2GHz'
#  'Intel Core i7 8550U 1.8GHz' 'Intel Core i5 8250U 1.6GHz'
#  'Intel Core i3 6006U 2GHz' 'Intel Core i7 2.8GHz'
#  'Intel Core M m3 1.2GHz' 'Intel Core i7 7500U 2.7GHz'
#  'Intel Core i7 2.9GHz' 'Intel Core i3 7100U 2.4GHz'
#  'Intel Atom x5-Z8350 1.44GHz' 'Intel Core i5 7300HQ 2.5GHz'
#  'AMD E-Series E2-9000e 1.5GHz' 'Intel Core i5 1.6GHz'
#  'Intel Core i7 8650U 1.9GHz' 'Intel Atom x5-Z8300 1.44GHz'
#  'AMD E-Series E2-6110 1.5GHz' 'AMD A6-Series 9220 2.5GHz'
#  'Intel Celeron Dual Core N3350 1.1GHz' 'Intel Core i3 7130U 2.7GHz'
#  'Intel Core i7 7700HQ 2.8GHz' 'Intel Core i5 2.0GHz'
#  'AMD Ryzen 1700 3GHz' 'Intel Pentium Quad Core N4200 1.1GHz'
# ...

# %% [markdown]
# # Feature engineering

# %%
import re
df['TouchScreen']="No"

# %%
#Extra feature "Touchscreen" was extracted (from the screenResolution column) and added to the dataset
#Laptops with touchscreen enabled displays are more costly than those without touchscreen capabilities
#(Personal opinion before EDA)

df.loc[df['ScreenResolution'].str.contains('Touchscreen'),'TouchScreen']="Yes"
df.tail(10)
# Out:
#                 TypeName  Inches                            ScreenResolution  \
# 1293            Notebook    15.6                 IPS Panel Full HD 1920x1080
# 1294            Notebook    15.6                           Full HD 1920x1080
# 1295            Notebook    15.6                                    1366x768
# 1296             Netbook    11.6                                    1366x768
# 1297            Notebook    15.6                                    1366x768
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# ...

# %%
df['ScreenResolution']=df['ScreenResolution'].str.extract('(\d\d\d\d?x\d\d\d\d?)',expand=True)
df.tail(10)
# Out:
#                 TypeName  Inches ScreenResolution  \
# 1293            Notebook    15.6        1920x1080
# 1294            Notebook    15.6        1920x1080
# 1295            Notebook    15.6         1366x768
# 1296             Netbook    11.6         1366x768
# 1297            Notebook    15.6         1366x768
# 1298  2 in 1 Convertible    14.0        1920x1080
# 1299  2 in 1 Convertible    13.3        3200x1800
# 1300            Notebook    14.0         1366x768
# 1301            Notebook    15.6         1366x768
# 1302            Notebook    15.6         1366x768
#
#                                        Cpu   Ram              Memory  \
# 1293           Intel Core i7 6700HQ 2.6GHz   8GB             1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz   6GB        1.0TB Hybrid
# 1295            Intel Core i7 7500U 2.7GHz   8GB             1TB HDD
# 1296  Intel Celeron Dual Core N3060 1.6GHz   2GB  32GB Flash Storage
# ...

# %%
#Removal of units : GB,Kg

df['Ram']=df['Ram'].str.extract('(\d\d?)',expand=True)
df['Weight']=df['Weight'].str.extract('(\d\.\d\d?|\d)',expand=True)
df.head(6)
# Out:
#     TypeName  Inches ScreenResolution                         Cpu Ram  \
# 0  Ultrabook    13.3        2560x1600        Intel Core i5 2.3GHz   8
# 1  Ultrabook    13.3         1440x900        Intel Core i5 1.8GHz   8
# 2   Notebook    15.6        1920x1080  Intel Core i5 7200U 2.5GHz   8
# 3  Ultrabook    15.4        2880x1800        Intel Core i7 2.7GHz  16
# 4  Ultrabook    13.3        2560x1600        Intel Core i5 3.1GHz   8
# 5   Notebook    15.6         1366x768     AMD A9-Series 9420 3GHz   4
#
#                 Memory                           Gpu       OpSys Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640       macOS   1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000       macOS   1.34
# 2            256GB SSD         Intel HD Graphics 620       No OS   1.86
# 3            512GB SSD            AMD Radeon Pro 455       macOS   1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650       macOS   1.37
# ...

# %% [markdown]
# Simplification of Cpu column
#
# Intel cpus from dataset: intel i3, intel i5, intel i7, intel atom, intel celeron, intel pentium, intel xeon
#
# AMD cpus from dataset: AMD E-series, AMD FX, AMD A4,A5,A6,A8,A9,A10,A12, AMD Ryzen
#
# Others: Samsung

# %%
df['Cpu_copy']=0

#Intel processors
df.loc[df['Cpu'].str.contains('Core M'),'Cpu_copy']="Intel M "
df.loc[df['Cpu'].str.contains('Atom'),'Cpu_copy']="Intel Atom"
df.loc[df['Cpu'].str.contains('Celeron'),'Cpu_copy']="Intel Celeron"
df.loc[df['Cpu'].str.contains('Pentium'),'Cpu_copy']="Intel Pentium"
df.loc[df['Cpu'].str.contains('i3'),'Cpu_copy']="Intel i3"
df.loc[df['Cpu'].str.contains('i5'),'Cpu_copy']="Intel i5"
df.loc[df['Cpu'].str.contains('i7'),'Cpu_copy']="Intel i7"
df.loc[df['Cpu'].str.contains('Xeon'),'Cpu_copy']="Intel Xeon"


#AMD processors
df.loc[df['Cpu'].str.contains('AMD E-Series'),'Cpu_copy']="AMD E"
df.loc[df['Cpu'].str.contains('AMD FX'),'Cpu_copy']="AMD FX"
df.loc[df['Cpu'].str.contains('AMD A4'),'Cpu_copy']="AMD A4"
df.loc[df['Cpu'].str.contains('AMD A6'),'Cpu_copy']="AMD A6"
df.loc[df['Cpu'].str.contains('AMD A8'),'Cpu_copy']="AMD A8"
df.loc[df['Cpu'].str.contains('AMD A9'),'Cpu_copy']="AMD A9"
df.loc[df['Cpu'].str.contains('AMD A10'),'Cpu_copy']="AMD A10"
df.loc[df['Cpu'].str.contains('AMD A12'),'Cpu_copy']="AMD A12"
df.loc[df['Cpu'].str.contains('AMD Ryzen'),'Cpu_copy']="AMD Ryzen"



#Samsung processors
df.loc[df['Cpu'].str.contains('Samsung'),'Cpu_copy']="Samsung"


#print(list(df['Cpu_copy']).count(0))

# %%
# for i in range(len(df['Cpu_copy'])):
#     if df['Cpu_copy'][i]==0:
#         print(df['Cpu'][i])

df['Cpu']=df['Cpu_copy']
df.drop(columns=['Cpu_copy'],inplace=True)

# %%
df.head(30)
# Out:
#               TypeName  Inches ScreenResolution         Cpu Ram  \
# 0            Ultrabook    13.3        2560x1600    Intel i5   8
# 1            Ultrabook    13.3         1440x900    Intel i5   8
# 2             Notebook    15.6        1920x1080    Intel i5   8
# 3            Ultrabook    15.4        2880x1800    Intel i7  16
# 4            Ultrabook    13.3        2560x1600    Intel i5   8
# 5             Notebook    15.6         1366x768      AMD A9   4
# 6            Ultrabook    15.4        2880x1800    Intel i7  16
# 7            Ultrabook    13.3         1440x900    Intel i5   8
# 8            Ultrabook    14.0        1920x1080    Intel i7  16
# 9            Ultrabook    14.0        1920x1080    Intel i5   8
# 10            Notebook    15.6         1366x768    Intel i5   4
# 11            Notebook    15.6        1920x1080    Intel i3   4
# 12           Ultrabook    15.4        2880x1800    Intel i7  16
# 13            Notebook    15.6        1920x1080    Intel i3   4
# ...

# %% [markdown]
# Based on the dataset, laptops have four types of storage medium (SSD , HDD, Flash Storage, SSHD(Hybrid)). Therefore four separate columns/features were created for the each type of memory configuration. The config (SSD + SSD) will be dealt later.

# %%
#Dealing with HDD memory


df['HDD']=df['Memory'].str.extract('(\d\d\d?GB\sHDD|\dTB\sHDD|\d\.0TB\sHDD)',expand=True)
df['HDD']=df['HDD'].str.extract('(\d\d\d?|\dTB|\d\.0TB)',expand=True)

df['HDD']=df['HDD'].str.replace('(TB|\.0TB)','000',regex=True)
df['HDD'].fillna(0,inplace=True)

df.head(30)
# Out:
#               TypeName  Inches ScreenResolution         Cpu Ram  \
# 0            Ultrabook    13.3        2560x1600    Intel i5   8
# 1            Ultrabook    13.3         1440x900    Intel i5   8
# 2             Notebook    15.6        1920x1080    Intel i5   8
# 3            Ultrabook    15.4        2880x1800    Intel i7  16
# 4            Ultrabook    13.3        2560x1600    Intel i5   8
# 5             Notebook    15.6         1366x768      AMD A9   4
# 6            Ultrabook    15.4        2880x1800    Intel i7  16
# 7            Ultrabook    13.3         1440x900    Intel i5   8
# 8            Ultrabook    14.0        1920x1080    Intel i7  16
# 9            Ultrabook    14.0        1920x1080    Intel i5   8
# 10            Notebook    15.6         1366x768    Intel i5   4
# 11            Notebook    15.6        1920x1080    Intel i3   4
# 12           Ultrabook    15.4        2880x1800    Intel i7  16
# 13            Notebook    15.6        1920x1080    Intel i3   4
# ...

# %%
#Used for checking HDD column

# print(df['HDD'].unique())

# for i in range(len(df['HDD'])):
#     if df['HDD'][i]=='0000':
#             print(i)

# %%
#Dealing with SSD
df['SSD']=df['Memory'].str.extract('(\d\d?\d?GB\sSSD|\dTB\sSSD|\d\.0TB\sSSD)',expand=True)
df['SSD']=df['SSD'].str.extract('(\dTB|\d\d?\d?|\d\.0TB)',expand=True)

df['SSD']=df['SSD'].str.replace('(TB|\.0TB)','000',regex=True)
df['SSD'].fillna(0,inplace=True)


df.head()
# Out:
#     TypeName  Inches ScreenResolution       Cpu Ram               Memory  \
# 0  Ultrabook    13.3        2560x1600  Intel i5   8            128GB SSD
# 1  Ultrabook    13.3         1440x900  Intel i5   8  128GB Flash Storage
# 2   Notebook    15.6        1920x1080  Intel i5   8            256GB SSD
# 3  Ultrabook    15.4        2880x1800  Intel i7  16            512GB SSD
# 4  Ultrabook    13.3        2560x1600  Intel i5   8            256GB SSD
#
#                             Gpu  OpSys Weight  Price_euros TouchScreen HDD  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37      1339.69          No   0
# 1        Intel HD Graphics 6000  macOS   1.34       898.94          No   0
# 2         Intel HD Graphics 620  No OS   1.86       575.00          No   0
# 3            AMD Radeon Pro 455  macOS   1.83      2537.45          No   0
# 4  Intel Iris Plus Graphics 650  macOS   1.37      1803.60          No   0
#
#    SSD
# 0  128
# 1    0
# 2  256
# 3  512
# 4  256

# %% [markdown]
# Recall that some of the memory configuration consists of 256SSD +256SSD (2 SSD), or multiple SSDs, the total memory of both SSD config would be added. Therefore, this part of the dataset must be fixed manually.

# %%
#Shows columns with double SSD config

df.loc[df['Memory'].str.contains('(\d\d\dGB\sSSD\s\+\s\s\d\d\dGB\sSSD)',regex=True)]
# Out:
# C:\Users\ILLEGEAR\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                TypeName  Inches ScreenResolution       Cpu Ram  \
# 28            Ultrabook    15.6        1920x1080  Intel i7   8
# 266  2 in 1 Convertible    13.3        1920x1080  Intel i7   8
# 347           Ultrabook    15.6        1920x1080  Intel i7  16
# 901              Gaming    17.3        1920x1080  Intel i7  32
#
#                      Memory                      Gpu       OpSys Weight  \
# 28   256GB SSD +  256GB SSD   Intel UHD Graphics 620  Windows 10   1.88
# 266  512GB SSD +  512GB SSD   Intel UHD Graphics 620  Windows 10    1.1
# 347  512GB SSD +  256GB SSD   Intel UHD Graphics 620  Windows 10   1.88
# 901  256GB SSD +  256GB SSD  Nvidia GeForce GTX 980M  Windows 10   3.58
#
#      Price_euros TouchScreen HDD  SSD
# 28       1298.00          No   0  256
# ...

# %%
#Manully combining both SSD config into one

df['SSD'][28]='512'
df['SSD'][266]='1000'
df['SSD'][347]='768'
df['SSD'][901]='512'
# Out:
# <ipython-input-20-8dba0698c4f5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SSD'][28]='512'
# <ipython-input-20-8dba0698c4f5>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SSD'][266]='1000'
# <ipython-input-20-8dba0698c4f5>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SSD'][347]='768'
# <ipython-input-20-8dba0698c4f5>:6: SettingWithCopyWarning:
# ...

# %%
#Used for checking (as SettingWithCopyWarning given above), https://www.dataquest.io/blog/settingwithcopywarning/

df.loc[df['Memory'].str.contains('(\d\d\dGB\sSSD\s\+\s\s\d\d\dGB\sSSD)',regex=True)]
# Out:
# C:\Users\ILLEGEAR\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#                TypeName  Inches ScreenResolution       Cpu Ram  \
# 28            Ultrabook    15.6        1920x1080  Intel i7   8
# 266  2 in 1 Convertible    13.3        1920x1080  Intel i7   8
# 347           Ultrabook    15.6        1920x1080  Intel i7  16
# 901              Gaming    17.3        1920x1080  Intel i7  32
#
#                      Memory                      Gpu       OpSys Weight  \
# 28   256GB SSD +  256GB SSD   Intel UHD Graphics 620  Windows 10   1.88
# 266  512GB SSD +  512GB SSD   Intel UHD Graphics 620  Windows 10    1.1
# 347  512GB SSD +  256GB SSD   Intel UHD Graphics 620  Windows 10   1.88
# 901  256GB SSD +  256GB SSD  Nvidia GeForce GTX 980M  Windows 10   3.58
#
#      Price_euros TouchScreen HDD   SSD
# 28       1298.00          No   0   512
# ...

# %%
#Dealing with SSHD

df['SSHD']=df['Memory'].str.extract('(\d\d\dGB\sHybrid|\d\.0TB\sHybrid)',expand=True)
df['SSHD']=df['SSHD'].str.extract('(\d\d\d?|\d\.0TB)',expand=True)
df.loc[df['Memory'].str.contains('(\d\d\dGB\sHybrid|\d\.0TB\sHybrid)',regex=True)]
# Out:
# C:\Users\ILLEGEAR\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#       TypeName  Inches ScreenResolution       Cpu Ram  \
# 151     Gaming    15.6        1920x1080  Intel i7   8
# 976   Notebook    14.0         1366x768  Intel i5   4
# 1010    Gaming    15.6        1920x1080  Intel i5   8
# 1081    Gaming    17.3        1920x1080  Intel i7  32
# 1116    Gaming    17.3        1920x1080  Intel i7  16
# 1135  Notebook    15.6        1920x1080  Intel i7  16
# 1158  Notebook    15.6        1920x1080  Intel i5   8
# 1176  Notebook    15.6        1920x1080  Intel i7   4
# 1258  Notebook    15.6        1920x1080  Intel i7   8
# 1266  Notebook    15.6        1920x1080    AMD A9   6
# 1280  Notebook    15.6        1920x1080    AMD A9   6
# 1294  Notebook    15.6        1920x1080    AMD A9   6
#
# ...

# %%
df['SSHD']=df['SSHD'].str.replace('(TB|\.0TB)','000',regex=True)
df['SSHD'].fillna(0,inplace=True)
df['SSHD'].unique()
# Out:
# array([0, '1000', '508'], dtype=object)

# %%
#Dealing with Flash Storage
df['FStorage']=df['Memory'].str.extract('(\d\d\d?GB\sFlash)',expand=True)
df['FStorage']=df['FStorage'].str.extract('(\d\d\d?)',expand=True)
df['FStorage'].fillna(0,inplace=True)
print(df['FStorage'].unique())

df.head(10)
# Out:
# [0 '128' '256' '32' '64' '16' '512']
#     TypeName  Inches ScreenResolution       Cpu Ram               Memory  \
# 0  Ultrabook    13.3        2560x1600  Intel i5   8            128GB SSD
# 1  Ultrabook    13.3         1440x900  Intel i5   8  128GB Flash Storage
# 2   Notebook    15.6        1920x1080  Intel i5   8            256GB SSD
# 3  Ultrabook    15.4        2880x1800  Intel i7  16            512GB SSD
# 4  Ultrabook    13.3        2560x1600  Intel i5   8            256GB SSD
# 5   Notebook    15.6         1366x768    AMD A9   4            500GB HDD
# 6  Ultrabook    15.4        2880x1800  Intel i7  16  256GB Flash Storage
# 7  Ultrabook    13.3         1440x900  Intel i5   8  256GB Flash Storage
# 8  Ultrabook    14.0        1920x1080  Intel i7  16            512GB SSD
# 9  Ultrabook    14.0        1920x1080  Intel i5   8            256GB SSD
#
#                             Gpu       OpSys Weight  Price_euros TouchScreen  \
# ...

# %%
for i in range(len(df['HDD'])):
    if (df['HDD'][i]==0 and df['SSHD'][i]==0) and (df['SSD'][i]==0 and df['FStorage'][i]==0):
        print(i)
        
#All storage options engineered as no columns are all ==0

# %%
df.drop(columns=['Memory'],inplace=True)
df
# Out:
#                 TypeName  Inches ScreenResolution            Cpu Ram  \
# 0              Ultrabook    13.3        2560x1600       Intel i5   8
# 1              Ultrabook    13.3         1440x900       Intel i5   8
# 2               Notebook    15.6        1920x1080       Intel i5   8
# 3              Ultrabook    15.4        2880x1800       Intel i7  16
# 4              Ultrabook    13.3        2560x1600       Intel i5   8
# ...                  ...     ...              ...            ...  ..
# 1298  2 in 1 Convertible    14.0        1920x1080       Intel i7   4
# 1299  2 in 1 Convertible    13.3        3200x1800       Intel i7  16
# 1300            Notebook    14.0         1366x768  Intel Celeron   2
# 1301            Notebook    15.6         1366x768       Intel i7   6
# 1302            Notebook    15.6         1366x768  Intel Celeron   4
#
#                                Gpu       OpSys Weight  Price_euros  \
# 0     Intel Iris Plus Graphics 640       macOS   1.37      1339.69
# ...

# %% [markdown]
# Gpu column has a high variability of GPUs. Intel Gpus are all integrated GPUS (which have less GPU power than discrete GPUs). Nvidia GPUs are all discrete GPUs. The problem arises when we are analysing AMD branded GPUs. Some AMD GPUs are integrated and some are discrete. Labelling each AMD GPU would take significant effort and time which may or may not contribute to the modelling proccess later on. Due to this issue, I've decided to drop the entire GPU column for simplicity purposes.

# %%
df.drop(columns=['Gpu'],inplace=True)
df
# Out:
#                 TypeName  Inches ScreenResolution            Cpu Ram  \
# 0              Ultrabook    13.3        2560x1600       Intel i5   8
# 1              Ultrabook    13.3         1440x900       Intel i5   8
# 2               Notebook    15.6        1920x1080       Intel i5   8
# 3              Ultrabook    15.4        2880x1800       Intel i7  16
# 4              Ultrabook    13.3        2560x1600       Intel i5   8
# ...                  ...     ...              ...            ...  ..
# 1298  2 in 1 Convertible    14.0        1920x1080       Intel i7   4
# 1299  2 in 1 Convertible    13.3        3200x1800       Intel i7  16
# 1300            Notebook    14.0         1366x768  Intel Celeron   2
# 1301            Notebook    15.6         1366x768       Intel i7   6
# 1302            Notebook    15.6         1366x768  Intel Celeron   4
#
#            OpSys Weight  Price_euros TouchScreen   HDD  SSD SSHD FStorage
# ...

# %% [markdown]
# # Feature Engineered dataset saved to separate csv file

# %%
df.to_csv('feature_engineered_laptop.csv',index=False)
